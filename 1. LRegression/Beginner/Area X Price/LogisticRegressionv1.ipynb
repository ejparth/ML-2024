# %%
# !pip install pandas
# !pip install numpy
# Out:
# Collecting pandas
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2,>=1.23.2 (from pandas)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/61.0 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 61.0/61.0 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (from pandas) (2023.3.post1)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/11.6 MB 10.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/11.6 MB 20.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.8/11.6 MB 25.5 MB/s eta 0:00:01
#    -------------- ------------------------- 4.2/11.6 MB 24.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/11.6 MB 23.2 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.6 MB 22.7 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.6 MB 21.1 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.6 MB 21.1 MB/s eta 0:00:01
#    ------------------------ --------------- 7.0/11.6 MB 17.2 MB/s eta 0:00:01
#    ------------------------------- -------- 9.1/11.6 MB 20.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.6 MB 19.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.9/11.6 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 19.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.5/15.8 MB 30.7 MB/s eta 0:00:01
#    ------ --------------------------------- 2.4/15.8 MB 25.6 MB/s eta 0:00:01
#    -------- ------------------------------- 3.3/15.8 MB 23.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.2/15.8 MB 22.5 MB/s eta 0:00:01
#    ------------ --------------------------- 5.1/15.8 MB 21.9 MB/s eta 0:00:01
#    --------------- ------------------------ 6.0/15.8 MB 21.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.9/15.8 MB 21.1 MB/s eta 0:00:01
#    ------------------- -------------------- 7.8/15.8 MB 20.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.7/15.8 MB 20.6 MB/s eta 0:00:01
#    ------------------------ --------------- 9.6/15.8 MB 20.5 MB/s eta 0:00:01
#    -------------------------- ------------- 10.5/15.8 MB 20.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.4/15.8 MB 19.3 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.8 MB 19.3 MB/s eta 0:00:01
#    --------------------------------- ------ 13.2/15.8 MB 19.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.1/15.8 MB 19.3 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.8 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 17.2 MB/s eta 0:00:00
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.1 tzdata-2024.1
# Requirement already satisfied: numpy in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (1.26.4)
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ERROR: unknown command "installmatplotlib.pyplot"

# %%
# !pip install -U scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.1.post1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.4 kB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 60.4/60.4 kB 1.6 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Using cached threadpoolctl-3.3.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.1.post1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 10.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.8/10.6 MB 23.5 MB/s eta 0:00:01
#    ------------- -------------------------- 3.6/10.6 MB 25.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.7/10.6 MB 24.8 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.6 MB 23.5 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.6 MB 22.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.6 MB 23.4 MB/s eta 0:00:01
#    ------------------------------- -------- 8.3/10.6 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.1/10.6 MB 21.5 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 21.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 21.1 MB/s eta 0:00:00
# Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Downloading scipy-1.12.0-cp311-cp311-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    - -------------------------------------- 1.4/46.2 MB 44.6 MB/s eta 0:00:02
#    - -------------------------------------- 1.7/46.2 MB 26.5 MB/s eta 0:00:02
#    - -------------------------------------- 1.7/46.2 MB 26.5 MB/s eta 0:00:02
#    - -------------------------------------- 1.8/46.2 MB 10.2 MB/s eta 0:00:05
#    --- ------------------------------------ 3.9/46.2 MB 16.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.7/46.2 MB 17.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.5/46.2 MB 17.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.4/46.2 MB 17.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.4/46.2 MB 17.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.4/46.2 MB 17.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.8/46.2 MB 13.6 MB/s eta 0:00:03
#    ------ --------------------------------- 7.5/46.2 MB 13.7 MB/s eta 0:00:03
#    ------- -------------------------------- 8.2/46.2 MB 13.9 MB/s eta 0:00:03
#    ------- -------------------------------- 8.6/46.2 MB 13.3 MB/s eta 0:00:03
#    ------- -------------------------------- 8.7/46.2 MB 12.6 MB/s eta 0:00:03
#    -------- ------------------------------- 9.4/46.2 MB 12.8 MB/s eta 0:00:03
#    --------- ------------------------------ 11.5/46.2 MB 13.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 13.0/46.2 MB 16.4 MB/s eta 0:00:03
#    ------------ --------------------------- 13.9/46.2 MB 15.2 MB/s eta 0:00:03
#    ------------ --------------------------- 14.8/46.2 MB 15.6 MB/s eta 0:00:03
#    ------------- -------------------------- 15.7/46.2 MB 15.6 MB/s eta 0:00:02
#    -------------- ------------------------- 16.6/46.2 MB 15.6 MB/s eta 0:00:02
#    --------------- ------------------------ 17.5/46.2 MB 19.8 MB/s eta 0:00:02
#    --------------- ------------------------ 18.4/46.2 MB 19.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 19.3/46.2 MB 23.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 20.2/46.2 MB 22.6 MB/s eta 0:00:02
#    ------------------ --------------------- 21.1/46.2 MB 21.1 MB/s eta 0:00:02
#    ------------------- -------------------- 22.0/46.2 MB 19.8 MB/s eta 0:00:02
#    ------------------- -------------------- 22.9/46.2 MB 19.3 MB/s eta 0:00:02
#    -------------------- ------------------- 23.6/46.2 MB 18.7 MB/s eta 0:00:02
#    --------------------- ------------------ 24.4/46.2 MB 18.7 MB/s eta 0:00:02
#    --------------------- ------------------ 25.3/46.2 MB 18.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 26.2/46.2 MB 18.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 27.1/46.2 MB 18.7 MB/s eta 0:00:02
#    ------------------------ --------------- 28.0/46.2 MB 18.7 MB/s eta 0:00:01
#    ------------------------- -------------- 28.9/46.2 MB 18.7 MB/s eta 0:00:01
#    ------------------------- -------------- 29.8/46.2 MB 18.7 MB/s eta 0:00:01
#    -------------------------- ------------- 30.7/46.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------- ------------ 31.6/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 32.5/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 33.4/46.2 MB 18.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 34.3/46.2 MB 19.3 MB/s eta 0:00:01
#    ------------------------------ --------- 35.1/46.2 MB 18.7 MB/s eta 0:00:01
#    ------------------------------- -------- 36.0/46.2 MB 18.7 MB/s eta 0:00:01
#    ------------------------------- -------- 36.9/46.2 MB 18.7 MB/s eta 0:00:01
#    -------------------------------- ------- 37.7/46.2 MB 18.7 MB/s eta 0:00:01
#    --------------------------------- ------ 38.6/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.6/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 40.3/46.2 MB 18.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 41.3/46.2 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------ --- 42.1/46.2 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- -- 43.0/46.2 MB 18.7 MB/s eta 0:00:01
#    -------------------------------------- - 44.0/46.2 MB 18.7 MB/s eta 0:00:01
#    -------------------------------------- - 44.7/46.2 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  45.5/46.2 MB 18.2 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 13.6 MB/s eta 0:00:00
# Using cached threadpoolctl-3.3.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.4.1.post1 scipy-1.12.0 threadpoolctl-3.3.0

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.3-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.49.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.3 kB ? eta -:--:--
#      -------------------------------------- 162.3/162.3 kB 2.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (from matplotlib) (23.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\aakash saxena\documents\conda\envs\pythonproject\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.3-cp311-cp311-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/7.6 MB 20.0 MB/s eta 0:00:01
#    -------- ------------------------------- 1.7/7.6 MB 21.8 MB/s eta 0:00:01
#    --------------- ------------------------ 3.0/7.6 MB 20.9 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.6 MB 24.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.6/7.6 MB 23.7 MB/s eta 0:00:01
#    --------------------------------- ------ 6.5/7.6 MB 23.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.8/7.6 MB 21.8 MB/s eta 0:00:01
#    -------------------------------------- - 7.3/7.6 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 18.8 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.6 kB ? eta -:--:--
#    ---------------------------------------- 187.6/187.6 kB ? eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.49.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------------------------- ------- 1.8/2.2 MB 56.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 35.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp311-cp311-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --------------------- ------------------ 1.4/2.6 MB 45.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 33.5 MB/s eta 0:00:00
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.2 kB ? eta -:--:--
#    ---------------------------------------- 103.2/103.2 kB ? eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 kiwisolver-1.4.5 matplotlib-3.8.3 pillow-10.2.0 pyparsing-3.1.2

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('homeprices.csv')

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('Prices')
plt.scatter(df.area,df.price, color='red', marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
X_new = 3300
y_pred = reg.predict([[X_new]])
y_pred
# Out:
# C:\Users\Aakash Saxena\Documents\conda\envs\pythonProject\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
# Plot the data and the linear regression line
plt.scatter(df.area, df.price)
plt.plot(X_new, y_pred, color='red')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Simple Linear Regression')
plt.show()

# %% [markdown]
# calculating by doing

# %%
m = reg.coef_
b = reg.intercept_

# %%
y=m*X_new+b
y
# Out:
# array([628715.75342466])

# %%
p_df = pd.read_csv('predictprice.csv')
p_df
# Out:
#    area
# 0  1000
# 1  2500
# 2  3000
# 3  3200
# 4  3400
# 5  2300
# 6  1500
# 7  2345
# 8  6543
# 9  3223

# %%
df1 = reg.predict(p_df)

# %%
df1
# Out:
# array([ 316404.10958904,  520085.61643836,  587979.45205479,
#         615136.98630137,  642294.52054795,  492928.08219178,
#         384297.94520548,  499038.52739726, 1069075.17123288,
#         618260.10273973])

# %%
p_df['prices'] = df1
p_df
# Out:
#    area        prices
# 0  1000  3.164041e+05
# 1  2500  5.200856e+05
# 2  3000  5.879795e+05
# 3  3200  6.151370e+05
# 4  3400  6.422945e+05
# 5  2300  4.929281e+05
# 6  1500  3.842979e+05
# 7  2345  4.990385e+05
# 8  6543  1.069075e+06
# 9  3223  6.182601e+05

# %%
p_df.to_csv("Final_prediction.csv", index =False)

# %%
x_pred = reg.predict(p_df[['area']])
x_pred
# Out:
# array([ 316404.10958904,  520085.61643836,  587979.45205479,
#         615136.98630137,  642294.52054795,  492928.08219178,
#         384297.94520548,  499038.52739726, 1069075.17123288,
#         618260.10273973])

# %%
p_df.area
# Out:
# 0    1000
# 1    2500
# 2    3000
# 3    3200
# 4    3400
# 5    2300
# 6    1500
# 7    2345
# 8    6543
# 9    3223
# Name: area, dtype: int64

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('Prices')
plt.scatter(df.area,df.price, color='red', marker='+')
plt.plot(p_df.area, x_pred, color = 'blue')
